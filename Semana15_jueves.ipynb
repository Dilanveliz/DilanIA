# %% [markdown]
# <a href="https://colab.research.google.com/github/Dilanveliz/DilanIA/blob/main/Semana15_jueves.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

print(pd.__version__)

serieData=pd.Series(data=[100,200,300], index=['fernando', 'pedro', 'lucas'])
print(serieData)

print(serieData['fernando'])

print (serieData.index)

print('fernando' in serieData)
# Out:
# 2.0.3
# fernando    100
# pedro       200
# lucas       300
# dtype: int64
# 100
# Index(['fernando', 'pedro', 'lucas'], dtype='object')
# True

# %%
import pandas as pd

myDiccionario = {
    'one': pd.Series([100, 200, 300], index=['fernando', 'pedro', 'lucas']),
    'two': pd.Series([11, 12, 33], index=['julio', 'pedro', 'lucas'])
}

# SERIES Y DATAFRAMES
df = pd.DataFrame(myDiccionario)
print(df)

print(df.index)
print(df)
print('we are here............')
print(df.index)
print(df.columns)

print(df['two']['julio'])
# Out:
#             one   two
# fernando  100.0   NaN
# julio       NaN  11.0
# lucas     300.0  33.0
# pedro     200.0  12.0
# Index(['fernando', 'julio', 'lucas', 'pedro'], dtype='object')
#             one   two
# fernando  100.0   NaN
# julio       NaN  11.0
# lucas     300.0  33.0
# pedro     200.0  12.0
# we are here............
# Index(['fernando', 'julio', 'lucas', 'pedro'], dtype='object')
# Index(['one', 'two'], dtype='object')
# 11.0

# %%
import pandas as pd
df = pd.read_csv('/content/movies.csv')

# %%
df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
# [62423 rows x 3 columns]

# %%
df.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
df.tail(6)
# Out:
#        movieId                           title                  genres
# 62417   209155      Santosh Subramaniam (2008)   Action|Comedy|Romance
# 62418   209157                       We (2018)                   Drama
# 62419   209159       Window of the Soul (2001)             Documentary
# 62420   209163                Bad Poems (2018)            Comedy|Drama
# 62421   209169             A Girl Thing (2001)      (no genres listed)
# 62422   209171  Women of Devil's Island (1962)  Action|Adventure|Drama

# %%
del df['genres']

# %%
df
# Out:
#        movieId                               title
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
# [62423 rows x 2 columns]

# %%
df.shape
# Out:
# (62423, 2)

# %%
df.columns
# Out:
# Index(['movieId', 'title'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=62423, step=1)

# %%
tmp =df.iloc[255]

# %%
tmp
# Out:
# movieId                                     258
# title      Kid in King Arthur's Court, A (1995)
# Name: 255, dtype: object

# %%
tmp['movieId']
# Out:
# 258

# %%
'title' in df.columns
# Out:
# True

# %%
df.iloc[[100,200,300]]
# Out:
#      movieId                 title
# 100      102      Mr. Wrong (1996)
# 200      202  Total Eclipse (1995)
# 300      304      Roommates (1995)

# %%
df.describe()
# Out:
#              movieId
# count   62423.000000
# mean   122220.387646
# std     63264.744844
# min         1.000000
# 25%     82146.500000
# 50%    138022.000000
# 75%    173222.000000
# max    209171.000000

# %%
min_movieid = df['movieId'].min()
max_movieid = df['movieId'].max()
mean_movieid = df['movieId'].mean()

print("Valor mínimo de movieId:", min_movieid)
print("Valor máximo de movieId:", max_movieid)
print("Valor promedio de movieId:", mean_movieid)
# Out:
# Valor mínimo de movieId: 1
# Valor máximo de movieId: 209171
# Valor promedio de movieId: 122220.38764557935

# %%
movies=pd.read_csv('/content/movies.csv')
ratings=pd.read_csv('/content/ratings (1).csv')
tags=pd.read_csv('/content/tags (1).csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating     timestamp
# 0       1    296.0     5.0  1.147880e+09
# 1       1    306.0     3.5  1.147869e+09
# 2       1    307.0     5.0  1.147869e+09
# 3       1    665.0     5.0  1.147879e+09
# 4       1    899.0     3.5  1.147869e+09

# %%
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
print(movies.shape)
print(ratings.shape)
print(tags.shape)
# Out:
# (62423, 3)
# (3933227, 3)
# (1093360, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId     True
# rating      True
# dtype: bool

# %%
print(tags.shape)
aux1=tags.shape[0]
tags=tags.dropna()
aux2=tags.shape[0]
print(tags.shape)
print(aux1)
print(f'muestra eliminada en varibale tag',[aux1-aux2])
# Out:
# (1093344, 3)
# (1093344, 3)
# 1093344
# muestra eliminada en varibale tag [0]

# %%
print(ratings.columns)
print(ratings['rating'].max())

print(ratings['rating'].min())
#
calificacion_alta=ratings['rating']>=4
calificacion_baja=ratings['rating']<=2
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')
# 5.0
# 0.5

# %%
ratings[calificacion_alta]
# Out:
#          userId  movieId  rating
# 0             1    296.0     5.0
# 2             1    307.0     5.0
# 3             1    665.0     5.0
# 5             1   1088.0     4.0
# 8             1   1237.0     5.0
# ...         ...      ...     ...
# 3933220   25890   1198.0     4.0
# 3933221   25890   1199.0     5.0
# 3933222   25890   1200.0     4.0
# 3933223   25890   1206.0     4.0
# 3933224   25890   1214.0     5.0
#
# [1970368 rows x 3 columns]

# %%
ratings_despues=ratings[calificacion_alta]
print(ratings_despues.shape)
# Out:
# (1970368, 3)
